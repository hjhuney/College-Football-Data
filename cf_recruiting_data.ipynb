# %% [markdown]
# # Top College Football Recruits by Location
#
# * Collected from top 500 recruits on 247's recruiting service

# %%
# standard libraries
import os
import pandas as pd
import numpy as np

# web scrapping
import requests
import urllib.request
import bs4

# visualization
import altair as alt

# %%
# iterate through all files
for filename in os.listdir('2020'):
    print(filename)
# Out:
# cf1.html
# cf10.html
# cf2.html
# cf3.html
# cf4.html
# cf5.html
# cf6.html
# cf7.html
# cf8.html
# cf9.html

# %%
recruit_list = []
directory = '2020'

# iterate through all files
for filename in os.listdir(directory):
    if filename.endswith(".html"): 
        recruit_file = open(directory + "//" + filename)
        soup = bs4.BeautifulSoup(recruit_file)
        rank_box = soup.findAll('div', attrs={'class':'primary'})
        name_box = soup.findAll('a', attrs={"class": "rankings-page__name-link"})
        location_box = soup.findAll('span', attrs={'class':'meta'})
        score_box = soup.findAll('span', attrs={'class':'score'})
        
        for i in range(len(rank_box)):
            recruit_dict = {'Rank': int(rank_box[i].text.strip()), 
                            'Name': name_box[i].text.strip(), 
                           'Location': location_box[i].text.strip(), 
                           'Score': float(score_box[i].text.strip())}
        
            recruit_list.append(recruit_dict)
        
#         for i in name_box:
#             names.append(i.text.strip())
            
#         for i in location_box:
#             locations.append(i.text.strip())

# %%
recruit_list[:5]
# Out:
# [{'Rank': 1,
#   'Name': 'Bryan Bresee',
#   'Location': 'Damascus (Damascus, MD)',
#   'Score': 0.999},
#  {'Rank': 2,
#   'Name': 'Zachary Evans',
#   'Location': 'North Shore (Houston, TX)',
#   'Score': 0.9987},
#  {'Rank': 3,
#   'Name': 'Justin Flowe',
#   'Location': 'Upland (Upland, CA)',
#   'Score': 0.9985},
#  {'Rank': 4,
#   'Name': 'Paris Johnson Jr.',
#   'Location': 'St. Xavier (Cincinnati, OH)',
#   'Score': 0.998},
#  {'Rank': 5,
#   'Name': 'Julian Fleming',
#   'Location': 'Southern Columbia (Catawissa, PA)',
#   'Score': 0.9978}]

# %%
# create dataframe
df = pd.DataFrame(recruit_list)

# reorder columns
df = df[['Rank', 'Name', 'Location', 'Score']]

# add geographic features
df['Location'] = df['Location'].str.replace(')', '')
df['HS'] = df['Location'].str.split('(').str[0]
df['CityState'] = df['Location'].str.split('(').str[1]
df['City'] = df['CityState'].str.split(',').str[0]
df['State'] = df['CityState'].str.split(',').str[1]
df = df.drop(['Location'], axis=1)

# view first 20 rows
df.head(20)
# Out:
#     Rank                Name   Score                      HS  \
# 0      1        Bryan Bresee  0.9990               Damascus
# 1      2       Zachary Evans  0.9987            North Shore
# 2      3        Justin Flowe  0.9985                 Upland
# 3      4   Paris Johnson Jr.  0.9980             St. Xavier
# 4      5      Julian Fleming  0.9978      Southern Columbia
# 5      6       DJ Uiagalelei  0.9976         St. John Bosco
# 6      7      Sav'ell Smalls  0.9972       Kennedy Catholic
# 7      8        Jordan Burch  0.9971         Hammond School
# 8      9        Myles Murphy  0.9966              Hillgrove
# 9     10         Elias Ricks  0.9965              Mater Dei
# 10    11        Arik Gilbert  0.9961               Marietta
# 11    12         Kelee Ringo  0.9949                Saguaro
# 12    13     Mekhail Sherman  0.9946  St. John's College HS
# 13    14      Chris Braswell  0.9943    St. Frances Academy
# 14    15      Kendall Milton  0.9939               Buchanan
# 15    16       Rakim Jarrett  0.9933  St. John's College HS
# 16    17       Desmond Evans  0.9931             Lee County
# 17    18  Darnell Washington  0.9930           Desert Pines
# 18    19     Broderick Jones  0.9923               Lithonia
# 19    20    Demarkcus Bowman  0.9914               Lakeland
#
#              CityState            City State
# 0         Damascus, MD        Damascus    MD
# 1          Houston, TX         Houston    TX
# 2           Upland, CA          Upland    CA
# 3       Cincinnati, OH      Cincinnati    OH
# 4        Catawissa, PA       Catawissa    PA
# 5       Bellflower, CA      Bellflower    CA
# 6           Burien, WA          Burien    WA
# 7         Columbia, SC        Columbia    SC
# 8   Powder Springs, GA  Powder Springs    GA
# 9        Santa Ana, CA       Santa Ana    CA
# 10        Marietta, GA        Marietta    GA
# 11      Scottsdale, AZ      Scottsdale    AZ
# 12      Washington, DC      Washington    DC
# 13       Baltimore, MD       Baltimore    MD
# 14          Clovis, CA          Clovis    CA
# 15      Washington, DC      Washington    DC
# 16         Sanford, NC         Sanford    NC
# 17       Las Vegas, NV       Las Vegas    NV
# 18        Lithonia, GA        Lithonia    GA
# 19        Lakeland, FL        Lakeland    FL

# %%
# export to csv
df.to_csv(r'cf_recruits_2020.csv')

# %% [markdown]
# # Maps
